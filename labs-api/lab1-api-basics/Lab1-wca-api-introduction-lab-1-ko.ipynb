# %% [markdown]
# # 사전 준비
# - 실습에 사용할 가상환경을 실행합니다.
#   - cd wca4ej-workshop
#   - .venv/Scripts/activate
# - vscode에서 바로 설정하기
#   - vscode 하단에 select interpreter 선택하기
#   - <img src="./images/select_interpreter.png" width=600>
#   - 가상환경 생성하기
#   - <img src="./images/image2.png" width=600>
#   - venv 생성하기
#   - <img src="./images/image3.png" width=600>
#   - python 선택하기
#   - <img src="./images/image4.png" width=600>
#   - requirements 선택하기
#   - <img src="./images/image5.png" width=600>
#   - 생성된 가상환경 확인하기 (.venv)
#   - <img src="./images/image6.png" width=300>
#
#
# - 실습 노트북의 python 커널 환경을 선택합니다.
#   - VScode 우측 상단의 "Select Kernel" 을 클릭하여 실습에 사용하고자 하는 python 커널을 선택합니다.
#   - 터미널에서 사용할 python 버전과 동일한 버전으로 선택합니다.
#     - python --version
#     - pip --version
#
# - 실습을 시작하기 전에 .env(.env_sample 파일 참조) 파일을 생성하고 IAM_APIKEY를 입력하세요.(watsonx Code Assistant 서비스가 있는 IBM CLOUD에서 받은 API KEY)
#   - cd lab1-api-basics
#   - vi .env
#
# - 다음 명령어로 필요한 Python 라이브러리를 설치합니다
#   - pip install -r requirements.txt

# %% [markdown]
# watsonx Code Assistant를 사용하기 위해 필요한 유틸리티 모듈을 초기화 합니다.

# %%
from wca_utils import *
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# iam_apikey
# True

# %%
iam_apikey = os.environ.get("IAM_APIKEY")  # Loading IAM_APIKEY from .env
# print(iam_apikey)

# %% [markdown]
# ### Lab 1.1. Swagger 명세로부터 REST API 생성
#
# Watson Code Assistant (WCA) API와 상호작용하여, 주어진 프롬프트와 Swagger (OpenAPI 명세) 파일을 기반으로 파이썬 코드를 생성하는 과정을 보여줍니다. Flask 프레임워크를 사용하여 최소한의 기본 웹 API 만들고 있고 @app.route(URL 엔드포인트 정의)와 jsonify(JSON 응답을 생성하는 함수)만을 사용하도록 프롬프트를 작성하였습니다.
# 아래 셀을 실행하면 결과를 확인할 수 있으며, 다른 prompt나 Swagger 명세로 자유롭게 실험해 볼 수 있습니다.

# %%
# sample
text = """Create a minimal Flask API using only @app.route and jsonify, based on the given Swagger:""" # 프롬프트

payload = build_basic_prompt_paylod(text)
response = call_wca_url(payload=payload, apikey=iam_apikey, file_dict=["assets/petstore-minimal.json"]) # Swagger 파일
result = (response['response']['message']['content'])
print(result)
# Out:
# To create a minimal Flask API based on the provided Swagger specification, you'll need to set up a Flask application with a single route that returns a list of pets in JSON format. Here's how you can implement this:
#
# 1. **Install Flask**: If you haven't already, install Flask using pip:
#    ```bash
#    # Assisted by watsonx Code Assistant
#    # watsonx Code Assistant did not check whether this code suggestion might be similar to third party code.
#
#    pip install Flask
#    ```
#
# 2. **Create the Flask Application**: Create a Python file, for example, `app.py`, and add the following code:
#
# ```python
# # Assisted by watsonx Code Assistant
# # watsonx Code Assistant did not check whether this code suggestion might be similar to third party code.
#
# from flask import Flask, jsonify
#
# app = Flask(__name__)
#
# # Sample data for pets
# pets = [
#     {"id": 1, "name": "Felix", "tag": "cat"},
#     {"id": 2, "name": "Bella", "tag": "dog"},
#     {"id": 3, "name": "Charlie", "tag": "cat"}
# ]
#
# @app.route('/api/pets', methods=['GET'])
# def get_pets():
#     """
#     Returns all pets from the system that the user has access to.
#     """
#     return jsonify(pets)
#
# if __name__ == '__main__':
#     app.run(debug=True)
# ```
#
# 3. **Run the Flask Application**: Execute the script to start the Flask development server:
#    ```bash
#    # Assisted by watsonx Code Assistant
#    # watsonx Code Assistant did not check whether this code suggestion might be similar to third party code.
#
#    python app.py
#    ```
#
# 4. **Test the API**: Open a web browser or use a tool like `curl` or Postman to access `http://127.0.0.1:5000/api/pets`. You should receive a JSON response similar to:
#    ```json
#    // Assisted by watsonx Code Assistant
#    // watsonx Code Assistant did not check whether this code suggestion might be similar to third party code.
#
#    [
#      {"id": 1, "name": "Felix", "tag": "cat"},
#      {"id": 2, "name": "Bella", "tag": "dog"},
#      {"id": 3, "name": "Charlie", "tag": "cat"}
#    ]
#    ```
#
# This minimal Flask API adheres to the provided Swagger specification, serving a list of pets in JSON format when the `/api/pets` endpoint is accessed with a GET request.

# %% [markdown]
# ### Lab 1.2. Python 파일에 대한 설명 생성
#
# WCA API를 사용해 sample.py 파일의 내용을 설명합니다. 원하는 prompt나 코드 파일을 활용해 자유롭게 설명을 받아볼 수 있습니다.

# %%
text = """ Generate a simple explanation for the following code:  """ 
payload = build_basic_prompt_paylod(text)
response = call_wca_url(payload=payload, apikey=iam_apikey, file_dict=["assets/sample.py"]) 
result = (response['response']['message']['content'])
print(result)
# Out:
# ```
# // Assisted by watsonx Code Assistant
# // watsonx Code Assistant did not check whether this code suggestion might be similar to third party code.
#
# This code is a simple REST API for user management using FastAPI, a modern, fast (high-performance), web framework for building APIs with Python 3.6+ based on standard Python type hints. It connects to a SQL database to perform CRUD (Create, Read, Update, Delete) operations on user data.
#
# ere's a breakdown of the code:
#
# . **Importing necessary modules**: FastAPI and its dependencies for handling HTTP requests, managing database sessions, and importing User and UserUpdate schemas and the database connection function.
#
# . **Initializing FastAPI app**: An instance of the FastAPI application is created.
#
# . **Defining API endpoints**:
#
#   - **GET /users/**: Retrieves all users from the database.
#
#   - **GET /users/{user_id}/**: Fetches a user by their ID. If the user is not found, it raises an HTTPException with a 404 status code.
#
#   - **POST /users/**: Creates a new user. It expects a UserCreate object in the request body, adds the new user to the database session, commits the transaction, and returns the newly created user.
#
#   - **PUT /users/{user_id}/**: Updates a user's information by their ID. It expects a UserUpdate object in the request body. If the user is not found, it raises an HTTPException with a 404 status code. Upon successful update, it returns a success message.
#
#   - **DELETE /users/{user_id}/**: Deletes a user by their ID. If the user is not found, it raises an HTTPException with a 404 status code. Upon successful deletion, it returns a success message.
#
# he code assumes the existence of a User model, a Base for the SQLAlchemy ORM, and UserCreate/UserUpdate schemas for request validation, which are not detailed here. The `get_db` function is responsible for setting up and providing a database session.
# ```

# %% [markdown]
# ### Lab 1.3. 단위 테스트 코드 생성
#
# WCA API를 사용해 sample.py 파일에 대한 unit test 코드를 생성합니다.

# %%
text = """ Generate unit test framework for the following code: """ 
payload = build_basic_prompt_paylod(text)
response = call_wca_url(payload=payload, apikey=iam_apikey, file_dict=["assets/sample.py"]) 
result = (response['response']['message']['content'])
print(result)
# Out:
# ```python
# # Assisted by watsonx Code Assistant
#
# import pytest
# from app.database import get_db
# from app.models import User, Base
# Base.metadata.create_all(bind=get_db())  # Ensure the database tables are created before tests
#
# # Mock UserCreate and UserUpdate schemas for testing
# class MockUserCreate:
#     def __init__(self, name, email, password):
#         self.name = name
#         self.email = email
#         self.password = password
#
# class MockUserUpdate:
#     def __init__(self, name, email):
#         self.name = name
#         self.email = email
#
# # Fixtures for database session
# @pytest.fixture()
# def db_session():
#     db = get_db()
#     Base.metadata.create_all(bind=db)  # Create tables for testing
#     yield db
#     Base.metadata.drop_all(bind=db)  # Clean up after tests
#
# @pytest.fixture()
# def test_user_create(db_session):
#     Base.metadata.create_all(bind=db_session)  # Ensure tables are created for this test
#     user_create_data = MockUserCreate("Test User", "test@example.com", "password")
#     yield user_create_data
#     Base.metadata.drop_all(bind=db_session)  # Clean up after test
#
# @pytest.fixture()
# def existing_user(db_session, test_user_create):
#     Base.metadata.create_all(bind=db_session)  # Ensure tables are created for this test
#     new_user = User(name=test_user_create.name, email=test_user_create.email, password=test_user_create.password)
#     db_session.add(new_user)
#     db_session.commit()
#     db_session.refresh(new_user)
#     yield new_user
#     db_session.delete(new_user)
#     db_session.commit()
#
# # Test cases
# def test_get_all_users(app, db_session):
#     assert app.test_client().get("/users/").status_code == 200
#     assert isinstance(app.test_client().get("/users/").json(), list)
#
# def test_get_user_by_email(app, db_session, existing_user):
#     user_id = existing_user.id
#     response = app.test_client().get(f"/users/{user_id}")
#     assert response.status_code == 200
#     assert response.json() == {"id": user_id, "name": existing_user.name, "email": existing_user.email}
#
# def test_create_user(app, test_user_create, db_session):
#     response = app.test_client().post("/users/", json=test_user_create.__dict__)
#     assert response.status_code == 200
#     assert response.json()["name"] == test_user_create.name
#     assert response.json()["email"] == test_user_create.email
#
# def test_update_user_by_email(app, db_session, existing_user):
#     updated_data = MockUserUpdate("Updated Name", "updated_email@example.com")
#     response = app.test_client().put(f"/users/{existing_user.id}", json=updated_data.__dict__)
#     assert response.status_code == 200
#     assert response.json["message"] == "User updated successfully"
#     updated_user = db_session.query(User).filter(User.id == existing_user.id).first()
#     assert updated_user.name == updated_data.name
#     assert updated_user.email == updated_data.email
#
# def test_delete_user_by_email(app, db_session, existing_user):
#     response = app.test_client().delete(f"/users/{existing_user.id}")
#     assert response.status_code == 200
#     assert response.json["message"] == "User deleted successfully"
#     with pytest.raises(HTTPException):
#         db_session.query(User).filter(User.id == existing_user.id).first()
# ```
#
# This unit test framework uses the `pytest` library and covers all the endpoints of the FastAPI application. It includes fixtures for setting up a database session and creating test users. Each test case checks the HTTP status code and the response content for correctness. Note that actual password hashing should be implemented in a production environment, but for the sake of this test, we're assuming plain text passwords.
